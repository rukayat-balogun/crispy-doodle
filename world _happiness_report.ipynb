# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
read_file2015 = pd.read_csv("/home/rukayat/Documents/my csv file/world happiness report/2015.csv")

# %%
read_file2016 = pd.read_csv("/home/rukayat/Documents/my csv file/world happiness report/2016.csv")

# %%
read_file2017 = pd.read_csv("/home/rukayat/Documents/my csv file/world happiness report/2017.csv")

# %%
read_file2018 = pd.read_csv("/home/rukayat/Documents/my csv file/world happiness report/2018.csv")

# %%
read_file2019 = pd.read_csv("/home/rukayat/Documents/my csv file/world happiness report/2019.csv")

# %%
read_file2020 = pd.read_csv("/home/rukayat/Documents/my csv file/world happiness report/2020.csv")

# %%
read_file2015
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %%
read_file2016
# Out:
#          Country                           Region  Happiness Rank  \
# 0        Denmark                   Western Europe               1
# 1    Switzerland                   Western Europe               2
# 2        Iceland                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4        Finland                   Western Europe               5
# ..           ...                              ...             ...
# 152        Benin               Sub-Saharan Africa             153
# 153  Afghanistan                    Southern Asia             154
# 154         Togo               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
#
#      Happiness Score  Lower Confidence Interval  Upper Confidence Interval  \
# 0              7.526                      7.460                      7.592
# ...

# %%
read_file2017
# Out:
#                       Country  Happiness.Rank  Happiness.Score  Whisker.high  \
# 0                      Norway               1            7.537      7.594445
# 1                     Denmark               2            7.522      7.581728
# 2                     Iceland               3            7.504      7.622030
# 3                 Switzerland               4            7.494      7.561772
# 4                     Finland               5            7.469      7.527542
# ..                        ...             ...              ...           ...
# 150                    Rwanda             151            3.471      3.543030
# 151                     Syria             152            3.462      3.663669
# 152                  Tanzania             153            3.349      3.461430
# 153                   Burundi             154            2.905      3.074690
# 154  Central African Republic             155            2.693      2.864884
#
# ...

# %%
read_file2018
# Out:
#      Overall rank         Country or region  Score  GDP per capita  \
# 0               1                   Finland  7.632           1.305
# 1               2                    Norway  7.594           1.456
# 2               3                   Denmark  7.555           1.351
# 3               4                   Iceland  7.495           1.343
# 4               5               Switzerland  7.487           1.420
# ..            ...                       ...    ...             ...
# 151           152                     Yemen  3.355           0.442
# 152           153                  Tanzania  3.303           0.455
# 153           154               South Sudan  3.254           0.337
# 154           155  Central African Republic  3.083           0.024
# 155           156                   Burundi  2.905           0.091
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 0             1.592                    0.874                         0.681
# ...

# %%
read_file2019
# Out:
#      Overall rank         Country or region  Score  GDP per capita  \
# 0               1                   Finland  7.769           1.340
# 1               2                   Denmark  7.600           1.383
# 2               3                    Norway  7.554           1.488
# 3               4                   Iceland  7.494           1.380
# 4               5               Netherlands  7.488           1.396
# ..            ...                       ...    ...             ...
# 151           152                    Rwanda  3.334           0.359
# 152           153                  Tanzania  3.231           0.476
# 153           154               Afghanistan  3.203           0.350
# 154           155  Central African Republic  3.083           0.026
# 155           156               South Sudan  2.853           0.306
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 0             1.587                    0.986                         0.596
# ...

# %%
read_file2020
# Out:
#                  Country name  Regional indicator  Ladder score  \
# 0                     Finland      Western Europe        7.8087
# 1                     Denmark      Western Europe        7.6456
# 2                 Switzerland      Western Europe        7.5599
# 3                     Iceland      Western Europe        7.5045
# 4                      Norway      Western Europe        7.4880
# ..                        ...                 ...           ...
# 148  Central African Republic  Sub-Saharan Africa        3.4759
# 149                    Rwanda  Sub-Saharan Africa        3.3123
# 150                  Zimbabwe  Sub-Saharan Africa        3.2992
# 151               South Sudan  Sub-Saharan Africa        2.8166
# 152               Afghanistan          South Asia        2.5669
#
#      Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                          0.031156      7.869766      7.747634
# 1                          0.033492      7.711245      7.579955
# ...

# %%
read_file2020.columns
# Out:
# Index(['Country name', 'Regional indicator', 'Ladder score',
#        'Standard error of ladder score', 'upperwhisker', 'lowerwhisker',
#        'Logged GDP per capita', 'Social support', 'Healthy life expectancy',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption', 'Ladder score in Dystopia',
#        'Explained by: Log GDP per capita', 'Explained by: Social support',
#        'Explained by: Healthy life expectancy',
#        'Explained by: Freedom to make life choices',
#        'Explained by: Generosity', 'Explained by: Perceptions of corruption',
#        'Dystopia + residual'],
#       dtype='object')

# %%
countries = read_file2020["Country name"].unique()

# %%
read_file2019["Country or region"].unique()
# Out:
# array(['Finland', 'Denmark', 'Norway', 'Iceland', 'Netherlands',
#        'Switzerland', 'Sweden', 'New Zealand', 'Canada', 'Austria',
#        'Australia', 'Costa Rica', 'Israel', 'Luxembourg',
#        'United Kingdom', 'Ireland', 'Germany', 'Belgium', 'United States',
#        'Czech Republic', 'United Arab Emirates', 'Malta', 'Mexico',
#        'France', 'Taiwan', 'Chile', 'Guatemala', 'Saudi Arabia', 'Qatar',
#        'Spain', 'Panama', 'Brazil', 'Uruguay', 'Singapore', 'El Salvador',
#        'Italy', 'Bahrain', 'Slovakia', 'Trinidad & Tobago', 'Poland',
#        'Uzbekistan', 'Lithuania', 'Colombia', 'Slovenia', 'Nicaragua',
#        'Kosovo', 'Argentina', 'Romania', 'Cyprus', 'Ecuador', 'Kuwait',
#        'Thailand', 'Latvia', 'South Korea', 'Estonia', 'Jamaica',
#        'Mauritius', 'Japan', 'Honduras', 'Kazakhstan', 'Bolivia',
#        'Hungary', 'Paraguay', 'Northern Cyprus', 'Peru', 'Portugal',
#        'Pakistan', 'Russia', 'Philippines', 'Serbia', 'Moldova', 'Libya',
# ...

# %%
countries = []
count = 0
for country in countries:
    if "Nigeria" in country:
        print("True")

# %%
countries = read_file2018["Country or region"].unique()
for country in countries:
    if "Nigeria" in country:
        print("True")
# Out:
# True

# %%
countries = read_file2017["Country"].unique()
for country in countries:
    if "Nigeria" in country:
        print("True")
# Out:
# True

# %%
countries = read_file2016["Country"].unique()
for country in countries:
    if "Nigeria" in country:
        print("True")
# Out:
# True

# %%
countries = read_file2015["Country"].unique()
for country in countries:
    if "Nigeria" in country:
        print("True")
# Out:
# True

# %%
read_file2015.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %%
hft_2015 = read_file2015[["Country","Health (Life Expectancy)", "Freedom", "Trust (Government Corruption)"]]
hft_2015.rename(columns={"Health (Life Expectancy)":"Health", "Trust (Government Corruption)":"Trust"}, inplace=True)
hft_2015
# Out:
# /home/rukayat/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:4133: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#          Country   Health  Freedom    Trust
# 0    Switzerland  0.94143  0.66557  0.41978
# 1        Iceland  0.94784  0.62877  0.14145
# 2        Denmark  0.87464  0.64938  0.48357
# 3         Norway  0.88521  0.66973  0.36503
# 4         Canada  0.90563  0.63297  0.32957
# ..           ...      ...      ...      ...
# 153       Rwanda  0.42864  0.59201  0.55191
# 154        Benin  0.31910  0.48450  0.08010
# 155        Syria  0.72193  0.15684  0.18906
# 156      Burundi  0.22396  0.11850  0.10062
# 157         Togo  0.28443  0.36453  0.10731
#
# [158 rows x 4 columns]

# %%
hft_2016 = read_file2016[["Country","Health (Life Expectancy)", "Freedom", "Trust (Government Corruption)"]]
hft_2016.rename(columns={"Health (Life Expectancy)":"Health", "Trust (Government Corruption)":"Corruption"}, inplace=True)
hft_2016
# Out:
# /home/rukayat/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:4133: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#          Country   Health  Freedom  Corruption
# 0        Denmark  0.79504  0.57941     0.44453
# 1    Switzerland  0.86303  0.58557     0.41203
# 2        Iceland  0.86733  0.56624     0.14975
# 3         Norway  0.79579  0.59609     0.35776
# 4        Finland  0.81091  0.57104     0.41004
# ..           ...      ...      ...         ...
# 152        Benin  0.21028  0.39747     0.06681
# 153  Afghanistan  0.17344  0.16430     0.07112
# 154         Togo  0.24811  0.34678     0.11587
# 155        Syria  0.62994  0.06912     0.17233
# 156      Burundi  0.15747  0.04320     0.09419
#
# [157 rows x 4 columns]

# %%
hft_2017 = read_file2017[["Country","Health..Life.Expectancy.","Freedom","Trust..Government.Corruption."]]
hft_2017.rename(columns={"Health..Life.Expectancy.":"Health", "Trust..Government.Corruption.":"Corruption"}, inplace=True)
hft_2017
# Out:
# /home/rukayat/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:4133: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#                       Country    Health   Freedom  Corruption
# 0                      Norway  0.796667  0.635423    0.315964
# 1                     Denmark  0.792566  0.626007    0.400770
# 2                     Iceland  0.833552  0.627163    0.153527
# 3                 Switzerland  0.858131  0.620071    0.367007
# 4                     Finland  0.809158  0.617951    0.382612
# ..                        ...       ...       ...         ...
# 150                    Rwanda  0.326425  0.581844    0.455220
# 151                     Syria  0.500533  0.081539    0.151347
# 152                  Tanzania  0.364509  0.390018    0.066035
# ...

# %%
read_file2018.columns
# Out:
# Index(['Overall rank', 'Country or region', 'Score', 'GDP per capita',
#        'Social support', 'Healthy life expectancy',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption'],
#       dtype='object')

# %%
hft_2018 = read_file2018[["Country or region","Healthy life expectancy","Freedom to make life choices","Perceptions of corruption"]]
hft_2018.rename(columns={"Country or region": "Country", "Healthy life expectancy": "Health","Freedom to make life choices":"Freedom", "Perceptions of corruption": "Corruption"} , inplace =True)
hft_2018
# Out:
# /home/rukayat/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:4133: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#                       Country  Health  Freedom  Corruption
# 0                     Finland   0.874    0.681       0.393
# 1                      Norway   0.861    0.686       0.340
# 2                     Denmark   0.868    0.683       0.408
# 3                     Iceland   0.914    0.677       0.138
# 4                 Switzerland   0.927    0.660       0.357
# ..                        ...     ...      ...         ...
# 151                     Yemen   0.343    0.244       0.064
# 152                  Tanzania   0.381    0.481       0.097
# 153               South Sudan   0.177    0.112       0.106
# ...

# %%
hft_2019 = read_file2019[["Country or region","Healthy life expectancy","Freedom to make life choices","Perceptions of corruption"]]
hft_2019.rename(columns={"Country or region": "Country", "Healthy life expectancy": "Health","Freedom to make life choices":"Freedom", "Perceptions of corruption": "Corruption"} , inplace =True)
hft_2019
# Out:
# /home/rukayat/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:4133: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#                       Country  Health  Freedom  Corruption
# 0                     Finland   0.986    0.596       0.393
# 1                     Denmark   0.996    0.592       0.410
# 2                      Norway   1.028    0.603       0.341
# 3                     Iceland   1.026    0.591       0.118
# 4                 Netherlands   0.999    0.557       0.298
# ..                        ...     ...      ...         ...
# 151                    Rwanda   0.614    0.555       0.411
# 152                  Tanzania   0.499    0.417       0.147
# 153               Afghanistan   0.361    0.000       0.025
# ...

# %%
hft_2020 = read_file2020[["Country name","Explained by: Healthy life expectancy","Explained by: Freedom to make life choices","Explained by: Perceptions of corruption"]]
hft_2020.rename(columns={"Country name": "Country", "Explained by: Healthy life expectancy": "Health","Explained by: Freedom to make life choices":"Freedom", "Explained by: Perceptions of corruption": "Corruption"} , inplace =True)
hft_2020
# Out:
# /home/rukayat/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:4133: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#                       Country    Health   Freedom  Corruption
# 0                     Finland  0.961271  0.662317    0.477857
# 1                     Denmark  0.979333  0.665040    0.495260
# 2                 Switzerland  1.040533  0.628954    0.407946
# 3                     Iceland  1.000843  0.661981    0.144541
# 4                      Norway  1.008072  0.670201    0.434101
# ..                        ...       ...       ...         ...
# 148  Central African Republic  0.000000  0.292814    0.028265
# 149                    Rwanda  0.572383  0.604088    0.485542
# 150                  Zimbabwe  0.375038  0.377405    0.080929
# ...

# %%
hft_2015.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Country  158 non-null    object
#  1   Health   158 non-null    float64
#  2   Freedom  158 non-null    float64
#  3   Trust    158 non-null    float64
# dtypes: float64(3), object(1)
# memory usage: 5.1+ KB

# %%
hft_2016.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 157 entries, 0 to 156
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Country     157 non-null    object
#  1   Health      157 non-null    float64
#  2   Freedom     157 non-null    float64
#  3   Corruption  157 non-null    float64
# dtypes: float64(3), object(1)
# memory usage: 5.0+ KB

# %%
hft_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 155 entries, 0 to 154
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Country     155 non-null    object
#  1   Health      155 non-null    float64
#  2   Freedom     155 non-null    float64
#  3   Corruption  155 non-null    float64
# dtypes: float64(3), object(1)
# memory usage: 5.0+ KB

# %%
hft_2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Country     156 non-null    object
#  1   Health      156 non-null    float64
#  2   Freedom     156 non-null    float64
#  3   Corruption  155 non-null    float64
# dtypes: float64(3), object(1)
# memory usage: 5.0+ KB

# %%
hft_2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Country     156 non-null    object
#  1   Health      156 non-null    float64
#  2   Freedom     156 non-null    float64
#  3   Corruption  156 non-null    float64
# dtypes: float64(3), object(1)
# memory usage: 5.0+ KB

# %%
hft_2020.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 153 entries, 0 to 152
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Country     153 non-null    object
#  1   Health      153 non-null    float64
#  2   Freedom     153 non-null    float64
#  3   Corruption  153 non-null    float64
# dtypes: float64(3), object(1)
# memory usage: 4.9+ KB

# %%
hft_2015.set_index("Country", inplace = True)

# %%
a = hft_2015.loc["Nigeria"]
a
names = ["Health", "Freedom", "Corruption"]
values = [0.16007, 0.34334, 0.04030]

plt.figure(figsize=(12, 3))

plt.subplot(131)
plt.bar(names, values)
plt.subplot(132)
plt.scatter(names, values)
plt.subplot(133)
plt.plot(names, values)
plt.suptitle('Graph of World Happiness Report of 2015')
plt.show()

# %%
hft_2016.set_index("Country", inplace = True)
b = hft_2016.loc["Nigeria"]
b
# Out:
# Health        0.05108
# Freedom       0.27854
# Corruption    0.03050
# Name: Nigeria, dtype: float64

# %%
names = ["Health", "Freedom", "Corruption"]
values = [0.05108, 0.27854, 0.03050]

plt.figure(figsize=(12, 3))

plt.subplot(131)
plt.bar(names, values)
plt.subplot(132)
plt.scatter(names, values)
plt.subplot(133)
plt.plot(names, values)
plt.suptitle('Graph of World Happiness Report of 2016')
plt.show()

# %%
hft_2017.set_index("Country", inplace = True)
c = hft_2017.loc["Nigeria"]
c
# Out:
# Health        0.056916
# Freedom       0.394953
# Corruption    0.026122
# Name: Nigeria, dtype: float64

# %%
names = ["Health", "Freedom", "Corruption"]
values = [0.056916, 0.394953, 0.026122]

plt.figure(figsize=(12, 3))

plt.subplot(131)
plt.bar(names, values)
plt.subplot(132)
plt.scatter(names, values)
plt.subplot(133)
plt.plot(names, values)
plt.suptitle('Graph of World Happiness Report of 2017')
plt.show()

# %%
hft_2018.set_index("Country", inplace = True)
d= hft_2018.loc["Nigeria"]
d
# Out:
# Health        0.048
# Freedom       0.462
# Corruption    0.032
# Name: Nigeria, dtype: float64

# %%
names = ["Health", "Freedom", "Corruption"]
values = [0.048, 0.462, 0.032]

plt.figure(figsize=(12, 3))

plt.subplot(131)
plt.bar(names, values)
plt.subplot(132)
plt.scatter(names, values)
plt.subplot(133)
plt.plot(names, values)
plt.suptitle('Graph of World Happiness Report of 2018')
plt.show()

# %%
hft_2019.set_index("Country", inplace = True)
e= hft_2019.loc["Nigeria"]
e
# Out:
# Health        0.245
# Freedom       0.426
# Corruption    0.041
# Name: Nigeria, dtype: float64

# %%
names = ["Health", "Freedom", "Corruption"]
values = [0.245, 0.426, 0.041]

plt.figure(figsize=(12, 3))

plt.subplot(131)
plt.bar(names, values)
plt.subplot(132)
plt.scatter(names, values)
plt.subplot(133)
plt.plot(names, values)
plt.suptitle('Graph of World Happiness Report of 2019')
plt.show()

# %%
hft_2020.set_index("Country", inplace = True)
f = hft_2020.loc["Nigeria"]
f
# Out:
# Health        0.167836
# Freedom       0.435079
# Corruption    0.047590
# Name: Nigeria, dtype: float64

# %%
names = ["Health", "Freedom", "Corruption"]
values = [0.167836, 0.435079, 0.047590]

plt.figure(figsize=(12, 3))

plt.subplot(131)
plt.bar(names, values)
plt.subplot(132)
plt.scatter(names, values)
plt.subplot(133)
plt.plot(names, values)
plt.suptitle('Graph of World Happiness Report of 2020')
plt.show()
